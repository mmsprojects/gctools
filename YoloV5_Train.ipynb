# %% [markdown]
# **MONTAR O GOOGLE DRIVE**

# %%
# Load the Drive helper and mount
from google.colab import drive
# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **BAIXAR E INSTALAR O REPOSITÓRIO YOLOV5 - ULTRALYTICS**

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.0.1+cu118 (Tesla T4)

# %% [markdown]
# **CONFIGURAÇÃO DO DATASET DO DRIVE**

# %% [markdown]
# /content/drive/MyDrive/AI/YOLOV5/DATASETS/torres.yml

# %%
import shutil
shutil.copy("/content/drive/MyDrive/AI/YOLOV5/lixao_v21.yaml","/content/yolov5/data/lixao_v21.yaml")
shutil.copy("/content/drive/MyDrive/AI/YOLOV5/yolov5s6_n2.yaml","/content/yolov5/models/hub/yolov5s6_nc2.yaml")
shutil.copytree("/content/drive/MyDrive/AI/YOLOV5/DATASETS/lixao_v21", "/content/lixao_v21")
# Out:
# '/content/yolov5/data/lixao_v21.yaml'

# %% [markdown]
# **INSTALAR VISUALIZADOR W&B**

# %%
# Weights & Biases  (optional) colar a api key no campo abaixo!
# %pip install -q wandb
import wandb
wandb.login(key=" ")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 15.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# **TREINAMENTO DA REDE NEURAL**

# %%
#wandb.init(settings=wandb.Settings(start_method='fork'))
# !python train.py --data /content/yolov5/data/lixao_v21.yaml --cfg /content/yolov5/models/hub/yolov5s6_nc2.yaml --weights yolov5s6.pt --batch-size 16 --epochs 200 --img-size 1280 --cache
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: Currently logged in as: mmsprojects. Use `wandb login --relogin` to force relogin
# train: weights=yolov5s6.pt, cfg=/content/yolov5/models/hub/yolov5s6_nc2.yaml, data=/content/yolov5/data/lixao_v21.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# ...

# %% [markdown]
# Salvar resultados no Drive

# %%
#shutil.copy("/content/yolov5/runs/train/exp/weights/best.pt","/content/drive/MyDrive/AI/YOLOV5/RESULDADOS/exp/best.pt")
# !cp /content/yolov5/runs/train/exp/weights/best.pt /content/drive/MyDrive/AI/YOLOV5/RESULTADOS/best.pt
